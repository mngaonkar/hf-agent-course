# %%
from smolagents import DuckDuckGoSearchTool, HfApiModel,load_tool,Tool, LiteLLMModel
import os
import yaml
from tools.web_search import DuckDuckGoSearchTool
from tools.final_answer import FinalAnswerTool
from langchain.agents import load_tools
from smolagents import CodeAgent, ToolCallingAgent

# %%
os.environ["HF_TOKEN"]="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"

# %%
with open("prompts-1.yaml", "r") as f:
    prompt_templates = yaml.safe_load(f)

# %%
model = LiteLLMModel(
        model_id="ollama/qwen2.5-coder",  # Or try other Ollama-supported models
        api_base="http://10.0.0.147:11434",  # Default Ollama local server
        num_ctx=8192,
)

# %%
final_answer = FinalAnswerTool()
web_search = DuckDuckGoSearchTool()

# %%
agent = CodeAgent(
    model = model,
    tools=[
        web_search,
        final_answer
    ],
    prompt_templates=prompt_templates,
    add_base_tools=True,
)

# %%
agent.run("What is the current age of the pope, raised to the power 0.36")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the current age of the pope, raised to the power 0.36                                                   │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama/qwen2.5-coder ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   pope_age_search = web_search(query="current pope age")
#   print("Pope age as per search:", pope_age_search)
# ...

# %%
agent = ToolCallingAgent(model=model, tools=[], add_base_tools=True)

# %%
agent.run("Could you get me the title of the page at url 'https://huggingface.co/blog'?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Could you get me the title of the page at url 'https://huggingface.co/blog'?                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama/qwen2.5-coder ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'visit_webpage' with arguments: {'url': 'https://huggingface.co/blog'}                            │
# ...

# %%
agent.logs
# Out:
# The 'logs' attribute is deprecated and will soon be removed. Please use 'self.memory.steps' instead.
# ...
